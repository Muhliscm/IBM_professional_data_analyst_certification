# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhliscm/IBM_professional_data_analyst_certification/blob/main/Web_scraping_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "http://www.ibm.com"

# %%
data = requests.get(url).text

# %%
data
# Out:
# '<!DOCTYPE html>\n<html lang="en-nl" dir="ltr">\n  <head>\n    <meta charset="utf-8" />\n<script>digitalData = {\n    "page": {\n        "category": [],\n        "pageInfo": {\n            "language": "en-NL",\n            "country": "NL",\n            "publisher": "IBM Corporation",\n            "version": "v18",\n            "ibm": {\n                "contentDelivery": "Drupal 8",\n                "contentProducer": "1706871 - IBM.com Global Homepage",\n                "owner": "Peter Barros/White Plains/IBM",\n                "siteID": "DRUPAL",\n                "contactModuleConfiguration": {\n                    "contactInformationBundleKey": {\n                        "focusArea": "Miscellaneous - About IBM",\n                        "languageCode": "en",\n                        "regionCode": "NL"\n                    },\n                    "contactModuleTranslationKey": {\n                        "languageCode": "en",\n                        "regionCode": "NL"\n            
# ...

# %%
soup = BeautifulSoup(data, "html5lib")

# %%
for link in soup.find_all('a'):
  print(link.get('href'))
# Out:
# https://www.ibm.com/nl/en
# https://www.ibm.com/sitemap/nl/en
# /nl-en/node/1706826
# https://1.dam.s81c.com/public/content/dam/worldwide-content/homepage/ul/g/7c/6c/12212020-best-of-2020-25440-2304x983.jpg
# https://1.dam.s81c.com/public/content/dam/worldwide-content/homepage/ul/g/f5/e3/12212020-best-of-2020-mobile-720x360.jpg
# https://www.ibm.com/thought-leadership/best-of/2020?lnk=nlhpv18l1
# /taxonomy/term/85416
# /nl-en/node/1706856
# https://newsroom.ibm.com/2020-12-21-IBM-to-Acquire-Nordcloud-to-Turbocharge-Its-Hybrid-Cloud-Consulting-Capability?lnk=nlhpv18nf
# /taxonomy/term/85416
# /nl-en/node/1706851
# /nl-en/node/1706831
# /nl-en/node/1706836
# /nl-en/node/1706841
# /nl-en/node/1706846
# /taxonomy/term/85416
# /nl-en/node/1706821
# /taxonomy/term/85416
# https://www.ibm.com/nl-en/employment/
# /nl-en/node/1706816
# https://www.ibm.com/nl-en/products/offers-and-discounts?lnk=STW_NL_HP_T_TL&psrc=NONE&pexp=DEF&lnk2=goto_MPDISC
# /nl-en/node/1706801
# /nl-en/node/1706806
# ...

# %%
for link in soup.find_all('img'):
  print(link.get('src'))
# Out:
# https://1.dam.s81c.com/public/content/dam/worldwide-content/homepage/ul/g/f5/e3/12212020-best-of-2020-mobile-720x360.jpg
# https://ibm.box.com/shared/static/3a1nke89wrzoiusbzh25ruuakv5x03hx.png
# https://ibm.box.com/shared/static/0jtr6nuueax5p3ex37e0majfyu1at9br.jpg
# https://1.dam.s81c.com/m/2f4c063729fde200/original/09142020-f-emerge-smarter-444x320.jpg
# https://1.dam.s81c.com/m/64ad5efc49c6474a/original/22052019-dede-thisisibm-444x320.png
# https://1.dam.s81c.com/m/10eba4be86e82c4b/original/IBM-Cloud-23059-700x420.png
# https://1.dam.s81c.com/m/30cc47a02cd1a73d/original/Planning-Analytics-22201-700x420.png
# https://1.dam.s81c.com/m/63a8764d67ad9224/original/IBM-Cloud-Pak-for-Automation-screen.png
# https://1.dam.s81c.com/public/content/dam/worldwide-content/other/ul/g/1f/a4/1fa47ece-96d8-4618-a22904deee1faedf.png

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %%
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, "html5lib")

# %%
table = soup.find('table')

# %%
for row in table.find_all('tr'):
  cols = row.find_all('td')
  color_name = cols[2].getText()
  color_code = cols[3].getText()
  print("{}--->{}".format(color_name, color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
